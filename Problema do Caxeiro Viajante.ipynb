# %% [markdown]
# # O Problema do Caxeiro Viajante

# %% [markdown]
# * PET - Física
# * Petiano: Wallysson Pereira da Silva
# * Data: 02/05/2025

# %% [markdown]
# $\quad$ O presente `Notebook` tem como objetivo introduzir o Problema do Caxeiro Viajante (TSP - Travelling Saleman Problem), junto com a apresentação de 3 método diferentes para a resolução do mesmo, sendo eles: O Método do Vizinho Mais Proximo (Nearest Neighbor **[1]**), o método Simulated Annealing **[2]** e o método Self-Organazing Maps **[3]**. Por sua própria natureza como um problema de otimização, o Problema do Caxeiro Viajante acaba tendo uma relação bem direta com a física, sobretude no contexto do desenvolvimentos dos seus métodos de solução.

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
from random import random, randrange # Usada na animação.
import matplotlib.animation as animation # Usada na animação.

# %% [markdown]
# ## Informações sobre as bibliotecas

# %%
# %load_ext version_information
# %version_information Matplotlib, Numpy
# Out:
# Software versions
# Python 3.13.0 64bit [MSC v.1941 64 bit (AMD64)]
# IPython 8.29.0
# OS Windows 11 10.0.26100 SP0
# Matplotlib 3.9.2
# Numpy 2.1.3
# Thu May 01 02:07:33 2025 Hora oficial do Brasil

# %% [markdown]
# ## Introdução

# %% [markdown]
# $\quad$ O enunciado do Problema do Caxeiro Viajente é bem simples: dado um conjunto de cidades (normalmente num plano), qual é a trajetória de menor caminho entre as cidades, de forma que cada cidade seja visitada uma única vez? Pense que uma cidade está sendo adotada como marco zero, de onde, a partir dela, sairemos em uma viagem, passando por todas as outras cidades uma única vez, e no fim retornando á essa cidade inicial. Um enunciado aparentemente simples, mas que esconde uma complexidade de solução inacreditável. Classificado como NP-hard, a dificuldade desse problema cresce rapidamente quanto maior o número de cidades.

# %% [markdown]
# $\quad$ O Problema do Caxeiro Viajante é um clássico problema de otimização da matemática, cujos métodos de solução acabam por influenciar (ou ser influenciado) pela física. Assim, o Problema do Caxeiro Viajante acaba tendo uma relação bem direta com a física. Durante esse `Notebook`, veremos 3 métodos diferentes de solução para esse problema. Para tal, vamos definir uma configuração inicial de cidades, geradas aleatoriamente num plano.

# %%
N = 35 # Número de cidades.
L = 100 # Largura do plano considerado.

np.random.seed(9)  # Para reprodutibilidade.
cidades = np.random.rand(N+1, 2) * L  # Coordenadas entre 0 e 100.
cidades[N] = cidades[0] # A última cidade do vetor é a cidade inicial.

# %% [markdown]
# ## Nearest Neighbor

# %% [markdown]
# $\quad$ Iniciaremos com um méotodo bem óbvio para a resolução desse problema, que naturalmente terá uma eficiência limitada. A lógica do método do Vizinho mais Próximo é simples: escolhemos uma cidades para sair (no nosso caso, adotaremos a cidade inicial do vertor), onde a partir dela calculamos qual cidade é a sua vizinha mais próxima, escolhendo tal resposta como a cidade próxima cidade que visitaremos. Chegando nessa outra cidade, repetimos o processo. À medida que vamos caminhando nas cidades, excluiremos as cidades já visitadas do conjunto de cidades possíveis, do contrário ficaríamos indo e voltando ente duas cidades. Assim, definimos o código:

# %%
def nearest_neighbor(cidades_NN):
    n = cidades_NN.shape[0] # Número de cidades... N + 1, contando a cidade inicial duas vezes.
    visitados = [0]  # Começamos na cidade 0.
    total_distance = 0.0 # Variável para armazenar a distância total no caminho.

    quadros_NN = [visitados.copy()] # Lista que armazenará passos da solução, depois sendo utilizada para gerar um gif.
    while len(visitados) < n: # Rodar enquanto o tamanho do vetor visitados for menor do que o número total de cidades
        current_city = visitados[-1] # Cidade atual do looping é sempre a última do vetor, que adicionada lá no passo anterior do looping.
        unvisited = [i for i in range(n) if i not in visitados] # Vetor dos índices da cidades ainda não visitadas.
        distances = [np.linalg.norm(cidades_NN[current_city] - cidades_NN[i]) for i in unvisited]
        nearest = unvisited[np.argmin(distances)] # Indice da cidade que tem a menor distancia.
        visitados.append(nearest) # Adicionar o índice da menor cidade às cidades visitadas.
        total_distance += min(distances) # Soma à distância total o percurso até a próxima cidade. 
        quadros_NN.append(visitados.copy()) # Adicionar o atual estado do vetor com os índices à um outro vetor, que depois será utilizado para fazer uma animação.

    
    # Voltar à cidade inicial
    total_distance += np.linalg.norm(cidades_NN[visitados[-1]] - cidades_NN[visitados[0]])
    visitados.append(visitados[0])
    quadros_NN.append(visitados.copy())

    return visitados, total_distance, quadros_NN

# %% [markdown]
# $\quad$ Resolvendo o problema, considerando a disposição inicial de cidades que definimos ainda na introdução.

# %%
cidades_NN = cidades.copy()

ordem_visita, distancia_total, quadros_NN = nearest_neighbor(cidades_NN)

# %% [markdown]
# Plotando a solução

# %%
print("Ordem das cidades visitadas:", ordem_visita)
print(f"Distância total percorrida: {distancia_total:.2f}")

# Plotar o caminho
plt.figure(figsize=(8, 6))
plt.plot(cidades_NN[ordem_visita, 0], cidades_NN[ordem_visita, 1], 'o-', color='blue')
plt.title('Caminho do Caixeiro Viajante (Nearest Neighbor)')
for i, (x, y) in enumerate(cidades_NN):
    plt.text(x + 1, y + 1, str(i), fontsize=9)
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.show()
# Out:
# Ordem das cidades visitadas: [0, 35, 4, 29, 2, 27, 33, 3, 1, 26, 28, 22, 16, 13, 6, 24, 32, 31, 11, 7, 25, 23, 9, 30, 10, 17, 5, 14, 15, 18, 12, 8, 20, 21, 19, 34, 0]
# Distância total percorrida: 520.25

# %% [markdown]
# $\quad$ O seguinte código gera um gif da evolução temporal da trajetória.

# %%
fig, ax = plt.subplots(figsize=(8,8))

def atualizar_SA(i):
    ax.clear()
    ax.axis('off')
    ax.plot(cidades_NN[quadros_NN[-1], 0], cidades_NN[quadros_NN[-1], 1], 'o', color='blue')
    ax.plot(cidades_NN[quadros_NN[i], 0], cidades_NN[quadros_NN[i], 1], 'o-', color='red')
    ax.set_xlim(0, L)
    ax.set_ylim(0, L)
    ax.set_title(f'Progresso {(i/len(quadros_NN)*100):.0f}%')
    ax.legend()
    ax.grid(True)

ani = animation.FuncAnimation(fig, atualizar_SA, np.arange(len(quadros_NN)), interval=150)
plt.close(fig)
ani.save('nearest nei.gif', writer='pillow', dpi=80)
# Out:
# C:\Users\noky2\AppData\Local\Temp\ipykernel_17724\3011323537.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ![nearest_neighbor](https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExMGdwMGhmZnZxcnkxMmdmNTM5ZWt5dmQwOGtvbzZndzE1MW12dzNnZiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3pPT3vwYQTbqBj3tbu/giphy.gif)

# %% [markdown]
# $\quad$ O maior problema desse método é sua alta variabilidade nos casos de muitas cidades. Isso é, o código pode evoluir e chegar no ponto onde a próxima mais próxima está do outro lado do mapa, obviamente ocasionando um deslocamente desnecessário.

# %% [markdown]
# ## Simulated Annealling

# %% [markdown]
# $\quad$ Proposto por Scott Kirkpatrick em 1985, o método Simulated Annealing tem sua base na físic estatística. O primeiro passo no méotod Simulated Annealing é estabelecer uma trajetória inicial, que no nosso caso será: sair do elemento **r[0]**, passar pelo elemento **r[1]**, depois pelo **r[2]**, até o elemento **r[N-1]** (que será novamente a cidade inicial). Tal caminho terá uma distância total percorrida associada. Após calcular e armazenar essa distância, nós realizaremos uma comutação aleatória entre dois elementos aleatórios do vetor de cidades, cujo alteração resultará numa nova distância total percorrida. Nesse ponto, realizaremos uma condicional, onde: caso a nova distância seja menor, aceitaremos ela imediatamente; caso a nova distãncia seja maior, nós aceitaremos ela com a probabilidade de Boltzzman

# %% [markdown]
# $$P(\Delta D) = e^{\frac{-\Delta D}{T}},$$

# %% [markdown]
# onde $\Delta D$ é a diferença entre o tamanho da trajetória nova e a anteior. Essa última condição nos dá uma maior probabilidade de escapar de mínimos locais, o que poderia não acontecer caso sempre rejeitássemos trajetórias que aumentam a distãncia total. O $T$ na equação (NUM) representa o temperatura atual do sistema. É certo que não estamos falando de temperatura no sentido físico, mas sim numa forma generalizada.

# %% [markdown]
# $\quad$ Essa temperatura tem um papel bem importante na convergência do método. Podemos observar na equação (NUM), que quanto maior o valor de $T$, maior será a probabilidade de aceitação de um estado com maior energia (pode-se pensar que o sistema está "agitado"). Assim, se a temperatura for mantida num valor consideravelmente alto, o sistema oscilará bastante, não convergindo nunca. Do contrário, se a temperatur $T$ for baixa, a probabilidade de aceitação de um estado com maior energia será quase nula, configurando um sistema estável. A estrágia do Simulated Anneling é iniciar o sistema com uma temperatura consideravelmente alta e ir diminuindo-a constantemente, de tal forma que o sistema convergirá para um mínimo (global ou mesmo local, já que o método não garante uma convergência absoluta) de energia. Na implementação código, utilizaremos um decaimento exponencial da temperatura, de tal forma que

# %% [markdown]
# $$ T = T_0e^{-\frac{t}{\tau}},$$

# %% [markdown]
# onde $T_0$ é a temperatura inicial e $\tau$ um parâmetro que controla a velocidade de decaimento.

# %%
aux = cidades.copy()
cidades_SA = np.zeros([N+1,2], float)
for i in range(N):
    cidades_SA[i] = aux[i]
cidades_SA[N] = cidades_SA[0]

# %% [markdown]
# $\quad$ Para cada para de cidades, teremos que calcular a distância euclidiana entre elas. Assim, vamos definir uma função que calcula essa distância entre duas cidades, justamente com umaa função que, dado o vetor com todas as cidades, calcula a distância total seguindo o caminho anteriomente definido (seguindo a ordem natural do vetor).

# %%
def mag(x):
    return np.sqrt(x[0]**2+x[1]**2) # Distancia euclidiana.

def distance(r): # Função para calcular a distância, dado um possível caminho entre as cidades.
    s = 0.0
    for i in range(N):
        dist = r[i+1]-r[i]
        s+=mag(dist)
    return(s)

# %% [markdown]
# $\quad$ Assim já podemos definir o corpo do código em si, a função que vai receber o vetor com a trajetória inicial, e retornar uma trajetória otimizada.

# %%
def evoluir(cidades_SA, N, L, Tmin, tau):
    Tmax = 10.0 # Temperatura inicial

    t = 0 # Tempo inicial
    T = Tmax
    quadros_SA = [cidades_SA.copy()] # Quadros para o gif desse método.
    distancias = [distance(cidades_SA)] # Vetor com as distâncias em cada evolução. 
    
    D = distance(cidades_SA)
    o = 0
    while(T>Tmin):
        t+=1
        T = Tmax*np.exp(-t/tau)

        c1, c2 = randrange(1,N),randrange(1,N) # Realizar a comultação entre 2 elementos.
        cidades_SA[[c1, c2]] = cidades_SA[[c2, c1]]
        Dnew = distance(cidades_SA) 
        dDist = Dnew-D
        if (random()<np.exp(-dDist/T)):
            D = Dnew
            if o%50 == 0: # Armazenar apenas alguns quadros.
                quadros_SA.append(cidades_SA.copy())
        else:
            cidades_SA[[c1, c2]] = cidades_SA[[c2, c1]] # Caso a mudança não seja aceita, desfazemos a troca.
        distancias.append(D)    

        o+=1

    return cidades_SA, quadros_SA, distancias

# %% [markdown]
# $\quad$ Definida a função, podemos fornecer a condição inicial anteriormente definida e obter o caminho otimizado, passando como argumento os devidos parâmetros.

# %%
cidades_SA = cidades.copy()

cidades_SA, quadros_SA, distancias = evoluir(cidades_SA, N, L, 1, 1e5)

# %% [markdown]
# $\quad$ Print da trajetória inicial (aleatoria) e a final (depois da otimização), junto com um gráfico da convergência do método:

# %%
fig, axes = plt.subplots(1, 3, figsize=(25, 4))  # 1 linha, 3 colunas

rotas = [quadros_SA[0], quadros_SA[-1]]
titulos = ["Rota inicial", "Rota final"]

for idx, rota in enumerate(rotas):
    for i in range(N):
        x1, y1 = rota[i]
        x2, y2 = rota[(i + 1) % N]  # conecta com o próximo, fecha o ciclo
        axes[idx].plot([x1, x2], [y1, y2], 'bo-')
        axes[idx].plot(x1, y1, f'C{i + 1}')
    axes[idx].grid(True)
    axes[idx].set_title(titulos[idx])

axes[2].plot(distancias)
axes[2].set_xlabel("Evolução Temporal")
axes[2].set_ylabel("Distância")
axes[2].set_title("Distância total da rota em função dos passos")
# Out:
# Text(0.5, 1.0, 'Distância total da rota em função dos passos')

# %% [markdown]
# $\quad$ O seguinte código é dedicado apenas à definição de uma animação, onde podemos analisar visualmente a convergência da trajetória.

# %%
fig, ax = plt.subplots(figsize=(8,8))

def atualizar_SA(i):
    ax.clear()
    ax.axis('off')
    cidades_quadro = quadros_SA[i]
    ax.plot(cidades_quadro[:, 0], cidades_quadro[:, 1], 'o-', color = 'blue', label='Caminho')
    ax.plot(cidades_quadro[:, 0], cidades_quadro[:, 1], 'o', color='red' , label='Cidades')
    ax.set_xlim(0, L)
    ax.set_ylim(0, L)
    ax.set_title(f'Progresso {(i/len(quadros_SA)*100):.0f}%')
    ax.legend()
    ax.grid(True)

ani = animation.FuncAnimation(fig, atualizar_SA, np.arange(len(quadros_SA)), interval=10-3)
plt.close(fig)
ani.save('simulated_annealing.gif', writer='pillow', dpi=80)

# %% [markdown]
# ![simulated_annealing](https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExbno3YXZwbnJwdm5yNGllcXV1NzQzYzYzend0YWlmYTM0YzkzdDZvdiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/k11IO6FLKxHoachMyS/giphy.gif)

# %% [markdown]
# $\quad$ O Simulated Annealing é um método de melhora de trajetória. Isso significa que, quanto melhor a trajetória inicial, a tendência é ou uma convergência mais rápida ou/e um output melhor no final dos passos. Assim, caso quisessemos melhorar a velocidade de convergência ou a acurária do Simulated Annealing aplicado ao PCV, poderíamos primeiro utilizar o método do Vizinho Mais Próximo (que tem custo computacional extremamente baixo) fornecer um caminho inicial mais otimizado do que quando o tomamemos de maneira aleatória.

# %% [markdown]
# ## Self-Organizing Maps

# %% [markdown]
# $\quad$ O terceiro e último método é de uma sofisticação considerável. Tendo sido proposto inicialmente nos anos 80, ela é baseada em técnicas de apredizado não supervisionado. O método Self-Organizing Maps pode ser definido como um conjunto de neuronios (especiaomente para o nosso caso, já aplicado ao Problema do Caxeiro Viajante), que, iniciados numa dada disposição, vão aos poucos convergindo às posições das cidades. A convergência se baseaia em: similaridade e influência entre os neuronios. O primeiro ponto, de similaridade, faz com que um neurônio convirga pra cidade mais próximo dele, e não para uma outra cidade mais longe. O segundo ponto, de influência entre os neurônios, causa uma interação que, além do neurônio convergir para uma dada cidade, ele também influenciará diretamente a convergência de neuronios próximos, dentro de um raio efetivo de interação. Para garantir a convergência do método, esse raio de interação vai diminuindo com o tempo. Para mais informações sobre o método, recomenda-se a leitura da referência **[2]**.

# %% [markdown]
# $\quad$ Definindo as constantes do método, junto com a disposição inicial dos neuronios:

# %%
cidades_SOM = cidades.copy()
num_neuronios = 10 * N  # Mais neurônios que cidades
num_epocas = 2000
alpha_inicial = 0.8 # Taxa de aprendizado inicial
raio_inicial = num_neuronios // 2 # Raio de interação???
decaimento_constante = num_epocas / np.log(raio_inicial) # Parâmetro para o decaimento do raio.


# Inicializar neurônios em um círculo
theta = np.linspace(0, 2*np.pi, num_neuronios, endpoint=False)
neuronios = np.column_stack((L*np.cos(theta), L*np.sin(theta))) * 0.5 + L//2  # Inicializa os neuronios num círculo

# Função de distância euclidiana
def distancia(a, b):
    return np.linalg.norm(a - b, axis=1)

# %% [markdown]
# $\quad$ Definido o corpo principal do código:

# %%
quadros_SOM = [neuronios.copy()]
# Treinamento SOM
for epoca in range(num_epocas):
    cidade_idx = np.random.randint(N)
    cidade = cidades_SOM[cidade_idx]

    # Encontrar neurônio vencedor
    distancias = distancia(neuronios, cidade)
    vencedor_idx = np.argmin(distancias)

    # Decaimento dos parâmetros
    alpha = alpha_inicial * np.exp(-epoca / num_epocas)
    raio = raio_inicial * np.exp(-epoca / decaimento_constante)

    # Atualizar neurônios
    for i in range(num_neuronios):
        # distância circular entre os neurônios (SOM é um anel)
        delta = min(abs(i - vencedor_idx), num_neuronios - abs(i - vencedor_idx))
        if delta < raio:
            influencia = np.exp(-delta**2 / (2 * (raio**2)))
            neuronios[i] += alpha * influencia * (cidade - neuronios[i])
    # Para a animação
    if epoca % 10 == 0:  # salva a cada 10 épocas (pode ajustar esse valor)
        quadros_SOM.append(neuronios.copy())

# %% [markdown]
# $\quad$ O caminho final (que minimiza a distância precorrida segundo o atual método) será obtida com base na disposição espacial final do

# %%
# Obter ordem final das cidades
# ordem = []
# for cidade in cidades_SOM:
#     distancias = distancia(neuronios, cidade)
#     idx = np.argmin(distancias)
#     ordem.append((idx, cidade))

# print(ordem)
# ordem.sort()
# caminho = np.array([cidade for _, cidade in ordem])



# for cidade in cidades_SOM:
#   distancias = distancia(neuronios, cidade)
#   indice = np.argmin(distncias)

# %% [markdown]
# $\quad$ Animação da evolução temporal do método

# %%
fig, ax = plt.subplots(figsize=(8,8))

def atualizar(frame_idx):
    ax.clear()
    ax.axis('off')
    neuronios_frame = quadros_SOM[frame_idx]
    ax.plot(neuronios_frame[:, 0], neuronios_frame[:, 1], 'o-', label='Neuronios')
    ax.scatter(cidades[:, 0], cidades[:, 1], c='red', label='Cidades')
    ax.set_xlim(0, L)
    ax.set_ylim(0, L)
    ax.set_title(f'Progresso {(frame_idx/len(quadros_SOM)*100):.0f}%')
    ax.legend()
    ax.grid(True)

ani = animation.FuncAnimation(fig, atualizar, frames=len(quadros_SOM), interval=10)
plt.close(fig)
ani.save('self organizing maps.gif', writer='pillow')

# %% [markdown]
# ![Plot3](https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExdzh3azEwOHAzNWJ5ejdvcWI0bTlwOXVpeG53bHU4aTA3a3ltYmxzOSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/JAXOl3WV6NLc0Kh5HB/giphy.gif)

# %% [markdown]
# ## Referencias

# %% [markdown]
# **[1]** *Mark Newman - Computational Physics (2013, University of Michigan)*
#
# **[2]** https://diego.codes/post/som-tsp/#fnref:1
#
# **[3]**
#
# **[4]**
